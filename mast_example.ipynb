# %%
from astroquery.mast import Mast, Observations
from astropy.io import fits
from astropy import table as tb
from astropy.time import Time

from glob import glob
import matplotlib.pyplot as plt
import matplotlib.image as img
from tqdm.notebook import tqdm
import numpy as np

directory = 'D:/jwst_data'
dirstar = directory + '/mastDownload/JWST/**/'

# %%
obs = Observations.query_criteria(
    obs_collection = 'JWST',
    instrument_name = 'NIRCAM/CORON',
    target_name = 'TWA-43',
    proposal_id = '4050',
    calib_level = '3'
)
print(f'Found {len(obs)} observations:')
for title in set(obs['obs_title']):
    print(f' - {title}')
# Out:
# Found 2 observations:
#  - Uncharted Worlds: Towards a Legacy of Direct Imaging of Sub-Jupiter Mass Exoplanets

# %%
obs
# Out:
# <Table masked=True length=46>
# intentType obs_collection provenance_name instrument_name project ... dataRights mtFlag  srcDen   obsid     objID
#    str7         str4            str7           str12        str4  ...    str6     bool  float64    str9     str10
# ---------- -------------- --------------- --------------- ------- ... ---------- ------ ------- --------- ----------
#    science           JWST         CALJWST    NIRCAM/CORON    JWST ...     PUBLIC  False     nan 215753769 1059130733
#    science           JWST         CALJWST    NIRCAM/CORON    JWST ...     PUBLIC  False     nan 215753770 1059130737
#    science           JWST         CALJWST    NIRCAM/CORON    JWST ...     PUBLIC  False     nan 215753686 1059130738
#    science           JWST         CALJWST    NIRCAM/CORON    JWST ...     PUBLIC  False     nan 215753771 1059130739
#    science           JWST         CALJWST    NIRCAM/CORON    JWST ...     PUBLIC  False     nan 216422695 1059132006
#    science           JWST         CALJWST    NIRCAM/CORON    JWST ...     PUBLIC  False     nan 216422696 1059132007
#    science           JWST         CALJWST    NIRCAM/CORON    JWST ...     PUBLIC  False     nan 216422697 1059132008
#    science           JWST         CALJWST    NIRCAM/CORON    JWST ...     PUBLIC  False     nan 216422698 1059132009
#    science           JWST         CALJWST    NIRCAM/CORON    JWST ...     PUBLIC  False     nan 216282904 1059132022
#    science           JWST         CALJWST    NIRCAM/CORON    JWST ...     PUBLIC  False     nan 216282906 1059132023
#    science           JWST         CALJWST    NIRCAM/CORON    JWST ...     PUBLIC  False     nan 216282909 1059132024
#    science           JWST         CALJWST    NIRCAM/CORON    JWST ...     PUBLIC  False     nan 216282915 1059132025
#        ...            ...             ...             ...     ... ...        ...    ...     ...       ...        ...
#    science           JWST         CALJWST    NIRCAM/CORON    JWST ...     PUBLIC  False     nan 216422561 1059132147
#    science           JWST         CALJWST    NIRCAM/CORON    JWST ...     PUBLIC  False     nan 216411101 1059132148
#    science           JWST         CALJWST    NIRCAM/CORON    JWST ...     PUBLIC  False     nan 216422562 1059132149
#    science           JWST         CALJWST    NIRCAM/CORON    JWST ...     PUBLIC  False     nan 216238098 1059143331
#    science           JWST         CALJWST    NIRCAM/CORON    JWST ...     PUBLIC  False     nan 216238099 1059143332
#    science           JWST         CALJWST    NIRCAM/CORON    JWST ...     PUBLIC  False     nan 216238100 1059143333
#    science           JWST         CALJWST    NIRCAM/CORON    JWST ...     PUBLIC  False     nan 216238101 1059143334
#    science           JWST         CALJWST    NIRCAM/CORON    JWST ...     PUBLIC  False     nan 216237443 1059143336
#    science           JWST         CALJWST    NIRCAM/CORON    JWST ...     PUBLIC  False     nan 216238102 1059143337
#    science           JWST         CALJWST    NIRCAM/CORON    JWST ...     PUBLIC  False     nan 216238103 1059143338
#    science           JWST         CALJWST    NIRCAM/CORON    JWST ...     PUBLIC  False     nan 216238104 1059143339
#    science           JWST         CALJWST    NIRCAM/CORON    JWST ...     PUBLIC  False     nan 216237444 1059143340
#    science           JWST         CALJWST    NIRCAM/CORON    JWST ...     PUBLIC  False     nan 216238105 1059143341

# %%
t = [Observations.get_product_list(o) for o in obs]
files = tb.unique(tb.vstack(t), keys = 'productFilename')
len(files)
# Out:
# 517

# %%
manifest = Observations.download_products(
    files,
    curl_flag=False,
    calib_level = [3],
    download_dir = directory
)
# Out:
# INFO: Found cached file D:/jwst_data\mastDownload\JWST\jw04050-c1007_t020_nircam_f444w-maskrnd-sub320a335r\jw04050-c1007_20251221t220746_coron3_00003_asn.json with expected size 10438. [astroquery.query]
# INFO: Found cached file D:/jwst_data\mastDownload\JWST\jw04050-c1007_t020_nircam_f200w-maskrnd-sub320a335r\jw04050-c1007_20251221t220746_coron3_00004_asn.json with expected size 10408. [astroquery.query]
# INFO: Found cached file D:/jwst_data\mastDownload\JWST\jw04050-c1007_t020_nircam_f200w-maskrnd-sub320a335r\jw04050-c1007_t020_nircam_f200w-maskrnd-sub320a335r_i2d.fits with expected size 3055680. [astroquery.query]
# INFO: Found cached file D:/jwst_data\mastDownload\JWST\jw04050-c1007_t020_nircam_f200w-maskrnd-sub320a335r\jw04050-c1007_t020_nircam_f200w-maskrnd-sub320a335r_i2d.jpg with expected size 6575. [astroquery.query]
# INFO: Found cached file D:/jwst_data\mastDownload\JWST\jw04050-c1007_t020_nircam_f200w-maskrnd-sub320a335r\jw04050-c1007_t020_nircam_f200w-maskrnd-sub320a335r_psfstack.fits with expected size 88548480. [astroquery.query]
# INFO: Found cached file D:/jwst_data\mastDownload\JWST\jw04050-c1007_t020_nircam_f200w-maskrnd-sub320a335r\jw04050-c1007_t020_nircam_f200w-maskrnd-sub320a335r_psfstack.jpg with expected size 9198. [astroquery.query]
# INFO: Found cached file D:/jwst_data\mastDownload\JWST\jw04050-c1007_t020_nircam_f444w-maskrnd-sub320a335r\jw04050-c1007_t020_nircam_f444w-maskrnd-sub320a335r_i2d.fits with expected size 3055680. [astroquery.query]
# INFO: Found cached file D:/jwst_data\mastDownload\JWST\jw04050-c1007_t020_nircam_f444w-maskrnd-sub320a335r\jw04050-c1007_t020_nircam_f444w-maskrnd-sub320a335r_i2d.jpg with expected size 12541. [astroquery.query]
# INFO: Found cached file D:/jwst_data\mastDownload\JWST\jw04050-c1007_t020_nircam_f444w-maskrnd-sub320a335r\jw04050-c1007_t020_nircam_f444w-maskrnd-sub320a335r_psfstack.fits with expected size 88548480. [astroquery.query]
# INFO: Found cached file D:/jwst_data\mastDownload\JWST\jw04050-c1007_t020_nircam_f444w-maskrnd-sub320a335r\jw04050-c1007_t020_nircam_f444w-maskrnd-sub320a335r_psfstack.jpg with expected size 25581. [astroquery.query]

# %%
fnames = glob(dirstar + '*.jpg')
for fname in tqdm(fnames):
    namearray = fname.split('/')[-1].split('_')
    plt.imshow(img.imread(fname))
    plt.title('_'.join(namearray[-2:]))
    plt.show()
